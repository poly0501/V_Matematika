# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
k=1
x = np.linspace(0,10,100)
plt.plot(x,np.cos(k*x))

k2=random.randint(2,10)
x2 = np.linspace(0,10,100)
plt.plot(x2,np.cos(k2*x2))
